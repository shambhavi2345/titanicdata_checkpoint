# %%
import numpy as np
import pandas as pd
from pandas import Series,DataFrame

# %%
titanic_data = pd.read_csv('train.csv')

# %%
titanic_data.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
titanic_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %% [markdown]
#    Some basic questions that has to be answered in this dataset
# 1. Who were the passengers on the Titanic?(age,gender)
# 2. What deck were the passengers are on and how does it relate to their      class?
# 3.From where did the passengers come from?
# 4.Who was alone and who was with family?
# 5.What Factors helpded someone  survive the sinking?

# %%
titanic_data.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
sns.catplot(x= "Sex" ,data = titanic_data, kind = "count")

# %%
sns.catplot(x= "Sex" ,data = titanic_data, kind = "count",hue = "Pclass",palette = ["b","y","g"])

# %%
sns.catplot(x="Pclass",data=titanic_data,kind="count",hue ="Sex",palette = ["b","grey"])

# %% [markdown]
# More males in third class than females

# %%
def male_female_child(passenger):
    age,sex = passenger

    if age<16:
        return"child"
    else:
        return sex

# %%
titanic_data["Person"]=titanic_data[["Age","Sex"]].apply(male_female_child,axis=1)

# %%
titanic_data[0:10]
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male   NaN      0
# ...

# %%
sns.catplot(x= "Pclass" ,data = titanic_data, kind = "count",hue = "Person",palette = ["b","y","g"])

# %% [markdown]
# There are more childern in  Third class ans very less in 1 class

# %%
sns.histplot(data = titanic_data,x="Age",bins=10)
# Out:
# <Axes: xlabel='Age', ylabel='Count'>

# %%
titanic_data["Age"].mean()
# Out:
# 29.69911764705882

# %%
titanic_data["Age"].mode()
# Out:
# 0    24.0
# Name: Age, dtype: float64

# %%
titanic_data["Person"].value_counts()
# Out:
# Person
# male      537
# female    271
# child      83
# Name: count, dtype: int64

# %%
fig = sns.FacetGrid(titanic_data,hue="Sex",aspect=4)
fig.map(sns.kdeplot,"Age",shade=True)
oldest=titanic_data["Age"].max()
fig.set(xlim=(0,oldest))
fig.add_legend()
# Out:
# C:\Users\lenovo\AppData\Roaming\Python\Python311\site-packages\seaborn\axisgrid.py:854: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   func(*plot_args, **plot_kwargs)
# C:\Users\lenovo\AppData\Roaming\Python\Python311\site-packages\seaborn\axisgrid.py:854: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   func(*plot_args, **plot_kwargs)

# %%
fig = sns.FacetGrid(titanic_data,hue="Person",aspect=4)
fig.map(sns.kdeplot,"Age",fill=True)
oldest=titanic_data["Age"].max()
fig.set(xlim=(0,oldest))
fig.add_legend()

# %%
fig = sns.FacetGrid(titanic_data,hue="Sex",aspect=4)
fig.map(sns.kdeplot,"Age",fill=True)
oldest=titanic_data["Age"].max()
fig.set(xlim=(0,oldest))
fig.add_legend()

# %%
fig = sns.FacetGrid(titanic_data,hue="Pclass",aspect=4)
fig.map(sns.kdeplot,"Age",fill=True)
oldest=titanic_data["Age"].max()
fig.set(xlim=(0,oldest))
fig.add_legend()

# %% [markdown]
# In this first class hass normal distribution i.e mean ,median and mode are equal but in second and third class the data is skewed much more towards 20 and 30 in range.

# %% [markdown]
# 2 QUESTION

# %%
titanic_data.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  Person
# 0      0         A/5 21171   7.2500   NaN        S    male
# 1      0          PC 17599  71.2833   C85        C  female
# 2      0  STON/O2. 3101282   7.9250   NaN        S  female
# 3      0            113803  53.1000  C123        S  female
# ...

# %%
deck = titanic_data["Cabin"].dropna()

# %%
deck.head()
# Out:
# 1      C85
# 3     C123
# 6      E46
# 10      G6
# 11    C103
# Name: Cabin, dtype: object

# %%
levels=[]

for level in deck:
    levels.append(level[0])

cabin_df = DataFrame(levels)
cabin_df.columns = ["Cabin"]
sns.catplot(x = "Cabin" ,data = cabin_df,hue = "Cabin", kind = "count",palette='dark:r',order=["A","B","C","D","E","F","T"])

# %%
titanic_data.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  Person
# 0      0         A/5 21171   7.2500   NaN        S    male
# 1      0          PC 17599  71.2833   C85        C  female
# 2      0  STON/O2. 3101282   7.9250   NaN        S  female
# 3      0            113803  53.1000  C123        S  female
# ...

# %%
sns.catplot(x="Embarked",data=titanic_data,kind="count",hue ="Pclass",order = ["C","Q","S"])

# %%
titanic_data["Alone"] = titanic_data.SibSp + titanic_data.Parch

# %%
titanic_data["Alone"]
# Out:
# 0      1
# 1      1
# 2      0
# 3      1
# 4      0
#       ..
# 886    0
# 887    0
# 888    3
# 889    0
# 890    0
# Name: Alone, Length: 891, dtype: int64

# %%
titanic_data["Alone"].loc[titanic_data["Alone"]>0] = "With Family"
titanic_data["Alone"].loc[titanic_data["Alone"]==0] = "Alone"
# Out:
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_1716\3882764211.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   titanic_data["Alone"].loc[titanic_data["Alone"]>0] = "With Family"
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_1716\3882764211.py:1: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value 'With Family' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   titanic_data["Alone"].loc[titanic_data["Alone"]>0] = "With Family"

# %%
titanic_data.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  Person        Alone
# 0      0         A/5 21171   7.2500   NaN        S    male  With Family
# 1      0          PC 17599  71.2833   C85        C  female  With Family
# 2      0  STON/O2. 3101282   7.9250   NaN        S  female        Alone
# ...

# %%
sns.catplot(x="Alone",data=titanic_data,kind="count", hue = "Alone",palette = ["b","grey"])

# %%
#Q5
titanic_data["Survivor"]=titanic_data.Survived.map({0:"no",1:"yes"})
sns.catplot(x="Survivor",data=titanic_data,kind="count",palette = "Set1")
# Out:
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_1716\1725731195.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.catplot(x="Survivor",data=titanic_data,kind="count",palette = "Set1")

# %%
# checking which factor is responsible for the survival
sns.catplot(x="Pclass",y ="Survived",data=titanic_data,kind = "point")

# %%
#for 3 class the  survival rates are lower

# %%
sns.lmplot(x="Age",y="Survived",data = titanic_data)

# %%
# it can be senn that ttht older passengers are less likely to survive

# %%
sns.lmplot(x="Age",y="Survived",hue="Pclass",data = titanic_data,palette= "winter")

# %%
# 3 xlass people have more deaths due to older age
